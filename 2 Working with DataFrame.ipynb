# %% [markdown]
# # 2 Working with DataFrame

# %%
import pandas as pd
import numpy as np
from IPython.display import Image

# %% [markdown]
# ## DataFrame Initialization and Modification

# %% [markdown]
# ### DataFrame Initialization

# %%
Image("images/dataframe-initialization.png", width=259.33)

# %%
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    })
print(df)
# Out:
#    col_0  col_1
# 0      0      1
# 1     10     11
# 2     20     21

# %%
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21

# %%
df = pd.DataFrame({
        'col_0': {'row_0': 0, 'row_1': 10, 'row_2': 20},
        'col_1': {'row_0': 1, 'row_1': 11, 'row_2': 21}
    })
print(df)
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21

# %% [markdown]
# ### DataFrame Adding/Deleting a Row/Column
# See also 4 Combining Multiple DataFrames

# %%
Image("images/dataframe-adding-column.png", width=351.67)

# %%
# Adding a column
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
df['col_2'] = [2, 21, 22]
print(df)
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
#        col_0  col_1  col_2
# row_0      0      1      2
# row_1     10     11     21
# row_2     20     21     22

# %%
Image("images/dataframe-adding-row.png", width=321.67)

# %%
# Adding a row
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
s = pd.Series([30, 31], index=['col_0', 'col_1'], name='row_3')
print(s)
df = df.append(s)
print(df)
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# col_0    30
# col_1    31
# Name: row_3, dtype: int64
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# row_3     30     31

# %%
Image("images/dataframe-deleting-column.png", width=291.67)

# %%
# Deleting a column
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
df_dropped = df.drop('col_1', axis=1, inplace=True)
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21

# %%
Image("images/dataframe-deleting-row.png", width=321.67)

# %%
# Deleting a row
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
df.drop(['row_0'], inplace=True)
print(df)
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
#        col_0  col_1
# row_1     10     11
# row_2     20     21

# %% [markdown]
# ## DataFrame Index, Columns and Values

# %% [markdown]
# ### Index (Row Index)

# %%
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.index)
print(df.index.values)
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# Index(['row_0', 'row_1', 'row_2'], dtype='object')
# ['row_0' 'row_1' 'row_2']

# %% [markdown]
# ### Columns (Column Index)

# %%
# DataFrame columns
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.columns)
print(df.columns.values)
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# Index(['col_0', 'col_1'], dtype='object')
# ['col_0' 'col_1']

# %% [markdown]
# ### Reindexing

# %%
# Reindexing rows
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
df_reindexed = df.reindex(index=['row_2', 'row_1', 'row_0'])
print(df_reindexed)
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
#        col_0  col_1
# row_2     20     21
# row_1     10     11
# row_0      0      1

# %%
# Reindexing columns
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
df_reindexed = df.reindex(columns=['col_1', 'col_0'])
print(df_reindexed)
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
#        col_1  col_0
# row_0      1      0
# row_1     11     10
# row_2     21     20

# %% [markdown]
# ### Values

# %%
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.values)
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# [[ 0  1]
#  [10 11]
#  [20 21]]

# %% [markdown]
# ### Transpose

# %%
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.T)
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
#        row_0  row_1  row_2
# col_0      0     10     20
# col_1      1     11     21

# %% [markdown]
# ## DataFrame Selecting

# %% [markdown]
# ### Label with .loc

# %%
Image("images/dataframe-selecting-column-label.png", width=152)

# %%
# df.loc[:, col_label] selecting columns
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.loc[:, 'col_0'])
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# row_0     0
# row_1    10
# row_2    20
# Name: col_0, dtype: int64

# %%
Image("images/dataframe-selecting-row-label.png", width=152)

# %%
# df.loc[row_label] selecting rows
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.loc['row_0'])
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# col_0    0
# col_1    1
# Name: row_0, dtype: int64

# %% [markdown]
# ### Position with .iloc

# %%
Image("images/dataframe-selecting-column-position.png", width=152)

# %%
# df.iloc[:, col_position] selecting columns
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.iloc[:, 0])
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# row_0     0
# row_1    10
# row_2    20
# Name: col_0, dtype: int64

# %%
Image("images/dataframe-selecting-row-position.png", width=152)

# %%
# df.iloc[row_position] selecting rows
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.iloc[0])
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# df.iloc[row_position] selects rows
# col_0    0
# col_1    1
# Name: row_0, dtype: int64

# %% [markdown]
# ### Mixing Label and Position

# %%
Image("images/dataframe-selecting-column-label-row-position.png", width=152)

# %%
# df.loc[df.index[row_position], col_label]
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.loc[df.index[2], 'col_1'])
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# 21

# %%
Image("images/dataframe-selecting-column-position-row-label.png", width=152)

# %%
# df.loc[row_label, df.colums[col_position]]
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.loc['row_2', df.columns[1]])
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# 21

# %% [markdown]
# ### With [ ]

# %%
# df[col_label] selects columns
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df['col_0'])
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# row_0     0
# row_1    10
# row_2    20
# Name: col_0, dtype: int64

# %%
# Convenience 1: [] with a slice to slice rows
# df[row_position_slice]
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df[1:2])
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
#        col_0  col_1
# row_1     10     11

# %%
# Convenience 2: [] with a boolean array to filter rows
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df['col_1']>10) # Returns a boolean array
print(df[df['col_0']>10])
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# row_0    False
# row_1     True
# row_2     True
# Name: col_1, dtype: bool
#        col_0  col_1
# row_2     20     21

# %%
# Convenience 3: [] with a boolean DataFrame to filter element
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df>10)
print(df[df>10])
# This is used to set values elementwise based on some criterion
df[df>10] = 999
print(df)
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
#        col_0  col_1
# row_0  False  False
# row_1  False   True
# row_2   True   True
#        col_0  col_1
# row_0    NaN    NaN
# row_1    NaN   11.0
# row_2   20.0   21.0
#        col_0  col_1
# row_0      0      1
# row_1     10    999
# row_2    999    999

# %% [markdown]
# ## DataFrame Sorting and Ranking

# %% [markdown]
# ### Sorting by Index

# %%
Image("images/dataframe-sorting-index-row.png", width=317.33)

# %%
# Sort rows by index
df = pd.DataFrame(np.arange(9).reshape((3,3)),
                  index=['row_2', 'row_1', 'row_0'],
                  columns=['col_2', 'col_1', 'col_0'])
print(df)
df_sorted = df.sort_index()
print(df_sorted)
# Out:
#        col_2  col_1  col_0
# row_2      0      1      2
# row_1      3      4      5
# row_0      6      7      8
#        col_2  col_1  col_0
# row_0      6      7      8
# row_1      3      4      5
# row_2      0      1      2

# %%
Image("images/dataframe-sorting-index-column.png", width=317.33)

# %%
# Sort columns by index
df = pd.DataFrame(np.arange(9).reshape((3,3)),
                  index=['row_2', 'row_1', 'row_0'],
                  columns=['col_2', 'col_1', 'col_0'])
print(df)
df_sorted = df.sort_index(axis=1)
print(df_sorted)
# Out:
#        col_2  col_1  col_0
# row_2      0      1      2
# row_1      3      4      5
# row_0      6      7      8
#        col_0  col_1  col_2
# row_2      2      1      0
# row_1      5      4      3
# row_0      8      7      6

# %% [markdown]
# ### Sorting by Values

# %%
Image("images/dataframe-sorting-value-row.png", width=317.33)

# %%
# Sort rows by values
df = pd.DataFrame(np.arange(9)[::-1].reshape((3,3)),
                  index=['row_0', 'row_1', 'row_2'],
                  columns=['col_0', 'col_1', 'col_2'])
print(df)
df_sorted = df.sort_values(by=['col_0'])
print(df_sorted)
# Out:
#        col_0  col_1  col_2
# row_0      8      7      6
# row_1      5      4      3
# row_2      2      1      0
#        col_0  col_1  col_2
# row_2      2      1      0
# row_1      5      4      3
# row_0      8      7      6

# %%
Image("images/dataframe-sorting-value-column.png", width=317.33)

# %%
# Sort columns by values
df = pd.DataFrame(np.arange(9)[::-1].reshape((3,3)),
                  index=['row_0', 'row_1', 'row_2'],
                  columns=['col_0', 'col_1', 'col_2'])
print(df)
df_sorted = df.sort_values(by=['row_0'], axis=1)
print(df_sorted)
# Out:
#        col_0  col_1  col_2
# row_0      8      7      6
# row_1      5      4      3
# row_2      2      1      0
#        col_2  col_1  col_0
# row_0      6      7      8
# row_1      3      4      5
# row_2      0      1      2

# %% [markdown]
# ### Ranking

# %%
Image("images/dataframe-ranking.png", width=259.67)

# %%
df = pd.DataFrame([
    [3, 4],
    [2, 5],
    [1, 4],
    [0, 5]
])
print(df)
print(df.rank(method='min'))
# Out:
#    0  1
# 0  3  4
# 1  2  5
# 2  1  4
# 3  0  5
#      0    1
# 0  4.0  1.0
# 1  3.0  3.0
# 2  2.0  1.0
# 3  1.0  3.0

# %% [markdown]
# Tie-Breaking Methods with Rank
#
# | Method  | Detail                                                    |
# |:--------|:----------------------------------------------------------|
# | Average | Average rank of group                                     |
# | Min     | Lowest rank in group                                      |
# | Max     | Highest rank in group                                     |
# | First   | Ranks assigned in order they appear in the array          |
# | Dense   | Like "min", but rank always increases by 1 between groups |

# %% [markdown]
# ## DataFrame Computations

# %% [markdown]
# ### Maximum Value

# %%
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.max())
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# col_0    20
# col_1    21
# dtype: int64

# %% [markdown]
# ### Minimum Value

# %%
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.min(axis=1))
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# row_0     0
# row_1    10
# row_2    20
# dtype: int64

# %% [markdown]
# ### Maximum Value Label

# %%
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.idxmax())
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# col_0    row_2
# col_1    row_2
# dtype: object

# %% [markdown]
# ### Minimum Value Label

# %%
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.idxmin(axis=1))
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# row_0    col_0
# row_1    col_0
# row_2    col_0
# dtype: object

# %% [markdown]
# ### Mean

# %%
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.mean(axis=1))
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# row_0     0.5
# row_1    10.5
# row_2    20.5
# dtype: float64

# %% [markdown]
# ### Median

# %%
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.median())
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# col_0    10.0
# col_1    11.0
# dtype: float64

# %% [markdown]
# ### Sum

# %%
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.sum())
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# col_0    30
# col_1    33
# dtype: int64

# %% [markdown]
# ### DataFrame Applying Function

# %% [markdown]
# ### Element-wise

# %%
Image("images/dataframe-applymap.png", width=372.67)

# %%
# DataFrame element-wise function application
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.applymap(np.square))
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
#        col_0  col_1
# row_0      0      1
# row_1    100    121
# row_2    400    441

# %% [markdown]
# ### Column-wise

# %%
Image("images/dataframe-apply-axis-0.png", width=372.67)

# %%
# DataFrame column-wise function application
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.apply(lambda x: x.max() - x.min()))
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# col_0    20
# col_1    20
# dtype: int64

# %% [markdown]
# ### Row-wise

# %%
Image("images/dataframe-apply-axis-1.png", width=372.67)

# %%
# DataFrame row-wise function application
df = pd.DataFrame({
        'col_0': [0, 10, 20],
        'col_1': [1, 11, 21]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.apply(lambda x: x.max() - x.min(), axis=1))
# Out:
#        col_0  col_1
# row_0      0      1
# row_1     10     11
# row_2     20     21
# row_0    1
# row_1    1
# row_2    1
# dtype: int64

# %% [markdown]
# ## DataFrame Missing Values

# %% [markdown]
# ### Counting

# %%
Image("images/dataframe-nan-counting.png", width=252.33)

# %%
# Count the number of null values
df = pd.DataFrame({
        'col_0': [0, 10, np.nan],
        'col_1': [1, np.nan, np.nan]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.count())
# Out:
#        col_0  col_1
# row_0    0.0    1.0
# row_1   10.0    NaN
# row_2    NaN    NaN
# col_0    2
# col_1    1
# dtype: int64

# %% [markdown]
# ### Filtering

# %%
Image("images/dataframe-nan-filtering.png", width=250)

# %%
# Whether the values are null
df = pd.DataFrame({
        'col_0': [0, 10, np.nan],
        'col_1': [1, np.nan, np.nan]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.isnull())
# Out:
#        col_0  col_1
# row_0    0.0    1.0
# row_1   10.0    NaN
# row_2    NaN    NaN
#        col_0  col_1
# row_0  False  False
# row_1  False   True
# row_2   True   True

# %%
# Whether the values are not null
df = pd.DataFrame({
        'col_0': [0, 10, np.nan],
        'col_1': [1, np.nan, np.nan]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
print(df.notnull())
# Out:
#        col_0  col_1
# row_0    0.0    1.0
# row_1   10.0    NaN
# row_2    NaN    NaN
#        col_0  col_1
# row_0   True   True
# row_1   True  False
# row_2  False  False

# %% [markdown]
# ### Dropping

# %%
Image("images/dataframe-nan-dropping.png", width=257.67)

# %%
# Drop rows with ANY null values
df = pd.DataFrame({
        'col_0': [0, 10, np.nan],
        'col_1': [1, np.nan, np.nan]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
df_dropped = df.dropna()
print(df_dropped)
# Out:
#        col_0  col_1
# row_0    0.0    1.0
# row_1   10.0    NaN
# row_2    NaN    NaN
#        col_0  col_1
# row_0    0.0    1.0

# %%
# Drop rows with ALL null values
df = pd.DataFrame({
        'col_0': [0, 10, np.nan],
        'col_1': [1, np.nan, np.nan]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
df_dropped = df.dropna(how='all')
print(df_dropped)
# Out:
#        col_0  col_1
# row_0    0.0    1.0
# row_1   10.0    NaN
# row_2    NaN    NaN
#        col_0  col_1
# row_0    0.0    1.0
# row_1   10.0    NaN

# %% [markdown]
# ### Filling

# %%
Image("images/dataframe-nan-filling.png", width=250)

# %%
# Fill the null values
df = pd.DataFrame({
        'col_0': [0, 10, np.nan],
        'col_1': [1, np.nan, np.nan]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
df_filled = df.fillna(999)
print(df_filled)
# Out:
#        col_0  col_1
# row_0    0.0    1.0
# row_1   10.0    NaN
# row_2    NaN    NaN
#        col_0  col_1
# row_0    0.0    1.0
# row_1   10.0  999.0
# row_2  999.0  999.0

# %%
# Fill the null values, column specific
df = pd.DataFrame({
        'col_0': [0, 10, np.nan],
        'col_1': [1, np.nan, np.nan]
    }, index = ['row_0', 'row_1', 'row_2'])
print(df)
df_filled = df.fillna({'col_0': 777, 'col_1': 888})
print(df_filled)
# Out:
#        col_0  col_1
# row_0    0.0    1.0
# row_1   10.0    NaN
# row_2    NaN    NaN
#        col_0  col_1
# row_0    0.0    1.0
# row_1   10.0  888.0
# row_2  777.0  888.0
