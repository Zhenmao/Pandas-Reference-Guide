# %% [markdown]
# # 1 Working with Series

# %%
import pandas as pd
import numpy as np
from IPython.display import Image

# %% [markdown]
# ## Series Initialization and Modification

# %% [markdown]
# ### Series Initialization

# %%
Image("images/series-initialization.png", width=119.67)

# %%
s = pd.Series([1, 2, 3])
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s = pd.Series([1, 2, 3], index=['a', 'b', 'c'])
print(s)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
s = pd.Series({'a': 1, 'b': 2, 'c': 3})
print(s)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %% [markdown]
# ### Series Adding/Deleting an Element

# %%
Image("images/series-adding.png", width=197.33)

# %%
# Adding an element
s = pd.Series([1, 2, 3], index=['a', 'b', 'c'])
print(s)
s['d'] = 4
print(s)
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
Image("images/series-deleting.png", width=197.33)

# %%
# Deleting an element
s = pd.Series([1, 2, 3], index=['a', 'b', 'c'])
print(s)
s.drop(['c'], inplace=True)
print(s)
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# a    1
# b    2
# dtype: int64

# %% [markdown]
# ## Series Index and Values

# %% [markdown]
# ### Index

# %%
s = pd.Series([1, 2, 3], index=['a', 'b', 'c'])
print(s)
print(s.index)
print(s.index.values)
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# Index(['a', 'b', 'c'], dtype='object')
# ['a' 'b' 'c']

# %% [markdown]
# ### Reindexing

# %%
s = pd.Series([1, 2, 3], index=['a', 'b', 'c'])
print(s)
s_reindexed = s.reindex(['d', 'c', 'b', 'a'], fill_value=0)
print(s_reindexed)
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# d    0
# c    3
# b    2
# a    1
# dtype: int64

# %% [markdown]
# ### Values

# %%
s = pd.Series([1, 2, 3], index=['a', 'b', 'c'])
print(s)
print(s.values)
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# [1 2 3]

# %% [markdown]
# ### Unique Values

# %%
s = pd.Series(['a', 'a', 'a', 'b', 'b', 'c'])
print(s)
print(s.unique())
# Out:
# 0    a
# 1    a
# 2    a
# 3    b
# 4    b
# 5    c
# dtype: object
# ['a' 'b' 'c']

# %% [markdown]
# ## Series Selecting

# %% [markdown]
# ### Label

# %%
Image("images/series-selecting-label.png", width=92)

# %%
s = pd.Series([1, 2, 3], index=['a', 'b', 'c'])
print(s)
print(s['a'])
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# 1

# %%
s = pd.Series([1, 2, 3], index=['a', 'b', 'c'])
print(s)
print(s['a':'b']) # Slicing with label, the endpoint is included
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# a    1
# b    2
# dtype: int64

# %% [markdown]
# ### Position

# %%
Image("images/series-selecting-position.png", width=92)

# %%
s = pd.Series([1, 2, 3], index=['a', 'b', 'c'])
print(s)
print(s[0])
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# 1

# %%
s = pd.Series([1, 2, 3], index=['a', 'b', 'c'])
print(s)
print(s[:1]) # Slicing with position, the endpoint is excluded
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# a    1
# dtype: int64

# %% [markdown]
# ## Series Sorting and Ranking

# %% [markdown]
# ### Sorting by Index

# %%
Image("images/series-sorting-index.png", width=197.33)

# %%
s = pd.Series([1, 2, 3], index=['c', 'b', 'a'])
print(s)
s_sorted = s.sort_index()
print(s_sorted)
# Out:
# c    1
# b    2
# a    3
# dtype: int64
# a    3
# b    2
# c    1
# dtype: int64

# %% [markdown]
# ### Sorting by Values

# %%
Image("images/series-sorting-value.png", width=197.33)

# %%
s = pd.Series([3, 2, 1], index=['a', 'b', 'c'])
print(s)
s_sorted = s.sort_values()
print(s_sorted)
# Out:
# a    3
# b    2
# c    1
# dtype: int64
# c    1
# b    2
# a    3
# dtype: int64

# %% [markdown]
# ### Ranking

# %%
Image("images/series-ranking.png", width=197.33)

# %%
s = pd.Series([1, 1, 2, 3, 3])
print(s.rank(method='average'))
# Out:
# 0    1.5
# 1    1.5
# 2    3.0
# 3    4.5
# 4    4.5
# dtype: float64

# %% [markdown]
# Tie-Breaking Methods with Rank
#
# | Method  | Detail                                                    |
# |:--------|:----------------------------------------------------------|
# | Average | Average rank of group                                     |
# | Min     | Lowest rank in group                                      |
# | Max     | Highest rank in group                                     |
# | First   | Ranks assigned in order they appear in the array          |
# | Dense   | Like "min", but rank always increases by 1 between groups |

# %% [markdown]
# ## Series Computatons
# See DataFrame Computations for more shared computation methods between Series and DataFrame

# %% [markdown]
# ### Counts of Unique Values

# %%
s = pd.Series(['a', 'a', 'a', 'b', 'b', 'c'])
print(s)
print(s.value_counts())
# Out:
# 0    a
# 1    a
# 2    a
# 3    b
# 4    b
# 5    c
# dtype: object
# a    3
# b    2
# c    1
# dtype: int64

# %% [markdown]
# ### Membership

# %%
s = pd.Series(['a', 'a', 'a', 'b', 'b', 'c'])
print(s)
print(s.isin(['b', 'c']))
# Out:
# 0    a
# 1    a
# 2    a
# 3    b
# 4    b
# 5    c
# dtype: object
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# dtype: bool

# %% [markdown]
# ### Series Applying Function (Element-wise)

# %%
Image("images/series-map.png", width=253)

# %%
# Series element-wise function application
s = pd.Series([1, 2, 3], index=['a', 'b', 'c'])
print(s)
print(s.map(np.square))
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# a    1
# b    4
# c    9
# dtype: int64

# %% [markdown]
# ## Series Missing Values

# %% [markdown]
# ### Counting

# %%
Image("images/series-nan-counting.png", width=167.67)

# %%
# Count the number of null values
s = pd.Series([0, 1, np.nan, np.nan, 4])
print(s)
print(s.count())
# Out:
# 0    0.0
# 1    1.0
# 2    NaN
# 3    NaN
# 4    4.0
# dtype: float64
# 3

# %% [markdown]
# ### Filtering

# %%
Image("images/series-nan-filtering.png", width=192.33)

# %%
# Whether the values are null
s = pd.Series([0, 1, np.nan, np.nan, 4])
print(s)
print(s.isnull())
# Out:
# 0    0.0
# 1    1.0
# 2    NaN
# 3    NaN
# 4    4.0
# dtype: float64
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# dtype: bool

# %%
# Whether the values are not null
s = pd.Series([0, 1, np.nan, np.nan, 4])
print(s)
print(s.notnull())
# Out:
# 0    0.0
# 1    1.0
# 2    NaN
# 3    NaN
# 4    4.0
# dtype: float64
# 0     True
# 1     True
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# ### Dropping

# %%
Image("images/series-nan-dropping.png", width=197.67)

# %%
# Drop the null values
s = pd.Series([0, 1, np.nan, np.nan, 4])
print(s)
s_dropped = s.dropna()
print(s_dropped)
# Out:
# 0    0.0
# 1    1.0
# 2    NaN
# 3    NaN
# 4    4.0
# dtype: float64
# 0    0.0
# 1    1.0
# 4    4.0
# dtype: float64

# %% [markdown]
# ### Filling

# %%
Image("images/series-nan-filling.png", width=197.67)

# %%
# Fill the null values
s = pd.Series([0, 1, np.nan, np.nan, 4])
print(s)
s_filled = s.fillna(999)
print(s_filled)
# Out:
# 0    0.0
# 1    1.0
# 2    NaN
# 3    NaN
# 4    4.0
# dtype: float64
# 0      0.0
# 1      1.0
# 2    999.0
# 3    999.0
# 4      4.0
# dtype: float64
